# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.stats import pearsonr, zscore

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
#Datos de propiedades
ruta = 'https://raw.githubusercontent.com/rasief/cartografia/master/melb_data.csv'
df = pd.read_csv(ruta)

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df = df.select_dtypes(exclude=['object'])

# %%
#Buscar nulos
df.isnull().sum()
# Out:
# Rooms               0
# Price               0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
#Borrado de datos nulos
df = df.dropna()
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6830 rows x 13 columns]

# %%
#Histograma
df.Price.hist(color='firebrick', bins=200, figsize=(10, 6))
# Out:
# <Axes: >

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df.plot(x = 'BuildingArea', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área menor o igual a 800
df0 = df[df["BuildingArea"]<=800]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6824 rows x 13 columns]

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'BuildingArea', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área cero
dfzero = df0[df0["BuildingArea"]<=15]
len(dfzero)
# Out:
# 56

# %%
#Se eliminan los registros de menos de 15 mts cuadrados de area
df0 = df0[df0["BuildingArea"]>4]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6773 rows x 13 columns]

# %%
#Se eliminan todos los datos que estén más allá de 3 desviaciones estándar
df0 = df0[(np.abs(zscore(df0['BuildingArea']))<=3)]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6678 rows x 13 columns]

# %%
#Boxplot
ax = sb.boxplot(data=df0['BuildingArea'].values, orient='h', color='yellow')
ax.set_title('Boxplot area construida');
plt.show()

# %%
#Múltiples diagramas por parejas
#sb.set_theme(style="ticks")
#sb.pairplot(df0, hue='Rooms')

# %%
#Correlación entre variables
corr_test = pearsonr(x = df['BuildingArea'], y = df['Price'])
print("Coeficiente de correlación de Pearson: ", corr_test[0])
print("P-value: ", corr_test[1])
# Out:
# Coeficiente de correlación de Pearson:  0.5204915813803511
# P-value:  0.0

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %%
df0[df0["Landsize"]==0].count()
# Out:
# Rooms            1007
# Price            1007
# Distance         1007
# Postcode         1007
# Bedroom2         1007
# Bathroom         1007
# Car              1007
# Landsize         1007
# BuildingArea     1007
# YearBuilt        1007
# Lattitude        1007
# Longtitude       1007
# Propertycount    1007
# dtype: int64

# %%
sb.set_theme(color_codes=True)
sb.set_theme(style="ticks")
ax = sb.regplot(x="BuildingArea", y="Price", data=df0, marker='+', x_jitter=0.2, y_jitter=0.2)
ax.set_title('Distribución de precio y area construida')
# Out:
# Text(0.5, 1.0, 'Distribución de precio y area construida')

# %%
#sb.pairplot(df0, kind='reg')

# %%
#Regresión lineal (Area construida vs. Precio)
x = df0["BuildingArea"]
y = df0["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     4315.
# Date:                Wed, 30 Aug 2023   Prob (F-statistic):               0.00
# Time:                        11:29:25   Log-Likelihood:                -97109.
# No. Observations:                6678   AIC:                         1.942e+05
# Df Residuals:                    6676   BIC:                         1.942e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.987e+05   1.45e+04     13.732      0.000     1.7e+05    2.27e+05
# BuildingArea  6220.9557     94.703     65.689      0.000    6035.308    6406.604
# ==============================================================================
# Omnibus:                     3831.529   Durbin-Watson:                   1.454
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           104788.984
# Skew:                           2.233   Prob(JB):                         0.00
# Kurtosis:                      21.885   Cond. No.                         361.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df0 = df0.drop(['Bedroom2', 'Postcode', 'Lattitude', 'Longtitude'], axis=1)

# %%
df0.dtypes
# Out:
# Rooms              int64
# Price            float64
# Distance         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# Propertycount    float64
# dtype: object

# %%
#Regresión lineal múltiple
x = df0.iloc[:,[2,6,7]]
y = df0["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     2874.
# Date:                Wed, 30 Aug 2023   Prob (F-statistic):               0.00
# Time:                        11:29:25   Log-Likelihood:                -96004.
# No. Observations:                6678   AIC:                         1.920e+05
# Df Residuals:                    6674   BIC:                         1.920e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.005e+07   2.79e+05     36.065      0.000     9.5e+06    1.06e+07
# Distance     -2.526e+04    915.901    -27.578      0.000   -2.71e+04   -2.35e+04
# BuildingArea  6760.1817     82.082     82.359      0.000    6599.275    6921.088
# YearBuilt    -4921.8683    142.677    -34.497      0.000   -5201.560   -4642.177
# ==============================================================================
# Omnibus:                     4796.581   Durbin-Watson:                   1.591
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           317769.618
# Skew:                           2.799   Prob(JB):                         0.00
# Kurtosis:                      36.327   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Predicciones con scikit-learn
train, test = train_test_split(df0, test_size = 0.20)
print("Ejemplos usados para entrenar: ", len(train))
print("Ejemplos usados para test: ", len(test))
# Out:
# Ejemplos usados para entrenar:  5342
# Ejemplos usados para test:  1336

# %%
#Regresión lineal múltiple
x = train.iloc[:,[2,6,7]]
y = train["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     2452.
# Date:                Wed, 30 Aug 2023   Prob (F-statistic):               0.00
# Time:                        11:29:25   Log-Likelihood:                -76668.
# No. Observations:                5342   AIC:                         1.533e+05
# Df Residuals:                    5338   BIC:                         1.534e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         9.895e+06   3.01e+05     32.876      0.000    9.31e+06    1.05e+07
# Distance     -2.572e+04   1017.754    -25.269      0.000   -2.77e+04   -2.37e+04
# BuildingArea  6818.8547     89.611     76.094      0.000    6643.181    6994.529
# YearBuilt    -4847.0075    154.153    -31.443      0.000   -5149.210   -4544.805
# ==============================================================================
# Omnibus:                     2607.159   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            48605.228
# Skew:                           1.884   Prob(JB):                         0.00
# Kurtosis:                      17.289   Cond. No.                     1.05e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Se definen las variables
x_train = train.iloc[:,[2,6,7]]
y_train = train.Price
x_test = test.iloc[:,[2,6,7]]
y_test = test.Price

# %%
#Entrenamiento del modelo
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# 2744     3400000.0
# 8602      360000.0
# 11896    1260000.0
# 5142      530000.0
# 6588     1500000.0
#            ...
# 10023     685000.0
# 1444      252000.0
# 4574     1230000.0
# 3746      349000.0
# 12034     835000.0
# Name: Price, Length: 5342, dtype: float64

# %%
#Predicción
y_pred = regr.predict(x_train)
y_pred
# Out:
# array([2159322.45959185,  471214.29625156,  981145.20448519, ...,
#        1788575.35129901,  381749.2511496 ,  844356.04539524])

# %%
print('Coeficientes:\n', regr.coef_)
print("Error cuadrático medio (Mean squared error): %.2f" % mean_squared_error(y_true=y_train, y_pred=y_pred, squared=False))
print('Coef. determinación (r^2): %.2f' % r2_score(y_train, y_pred))
print('w = ' + str(regr.coef_) + ', b = ' + str(regr.intercept_))
# Out:
# Coeficientes:
#  [-25717.91405781   6818.85473565  -4847.00747533]
# Error cuadrático medio (Mean squared error): 413752.33
# Coef. determinación (r^2): 0.58
# w = [-25717.91405781   6818.85473565  -4847.00747533], b = 9895185.116601748

# %%
predicciones = regr.predict(x_train)
for y, y_pred in list(zip(y_train, predicciones)) [:10]:
    print("Valor real: {:.2f} - Valor estimado: {:.2f}".format(y, y_pred))
# Out:
# Valor real: 3400000.00 - Valor estimado: 2159322.46
# Valor real: 360000.00 - Valor estimado: 471214.30
# Valor real: 1260000.00 - Valor estimado: 981145.20
# Valor real: 530000.00 - Valor estimado: 601999.08
# Valor real: 1500000.00 - Valor estimado: 1073603.40
# Valor real: 1075000.00 - Valor estimado: 1226502.73
# Valor real: 955000.00 - Valor estimado: 1171724.59
# Valor real: 1435000.00 - Valor estimado: 1047065.13
# Valor real: 1300000.00 - Valor estimado: 752147.91
# Valor real: 642500.00 - Valor estimado: 611661.60

# %%
predicciones = regr.predict(X=x_test)
print(predicciones[0:10,])
rmse = mean_squared_error(y_true=y_test, y_pred=predicciones, squared=False)
print(f"\nEl error (rmse) del test es: {rmse}")
# Out:
# [2178424.82310749  950845.26892118 1674876.08907543 1670406.13809731
#  2043401.92908578  806614.65253257 1307590.89819387  835889.19262663
#  1625233.29992318  782094.78928669]
#
# El error (rmse) del test es: 462376.2590360104

# %%
y_trainArray = np.array(y_train)
y_pred = regr.predict(x_train)
y_predArray = np.array(y_pred)

print("1. El Tipo es:", type(y_trainArray))
print("2. El tipo es:", type(y_predArray))

coefficient_of_determination = r2_score(y_trainArray, y_predArray)

print("")
print("El coeficiente de determinación es:", coefficient_of_determination)
print("El coeficiente de determinación de forma redondeada es:", round(coefficient_of_determination, 2))
print("")

plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = True
fig, ax1 = plt.subplots()
ax1.plot(y_trainArray, color="green")
ax2 = ax1.twinx()
ax2.plot(y_predArray, color="blue")
fig.tight_layout()
plt.show()
# Out:
# 1. El Tipo es: <class 'numpy.ndarray'>
# 2. El tipo es: <class 'numpy.ndarray'>
#
# El coeficiente de determinación es: 0.5795248338361878
# El coeficiente de determinación de forma redondeada es: 0.58
